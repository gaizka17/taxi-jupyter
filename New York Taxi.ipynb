# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\gaizka\Desktop\UNIR\GAIZKA\ASIGNATURAS\2 Semestre\TFM\codigo\data\green_tripdata_2013-08.csv", sep=',')
df
# Out:
#                                   VendorID lpep_pickup_datetime  \
# 2 2013-08-01 08:14:37  2013-08-01 09:09:06                    N
#   2013-08-01 09:13:00  2013-08-01 11:38:00                    N
#   2013-08-01 09:48:00  2013-08-01 09:49:00                    N
#   2013-08-01 10:38:35  2013-08-01 10:38:51                    N
#   2013-08-01 11:51:45  2013-08-01 12:03:52                    N
# ...                                    ...                  ...
#   2013-08-31 23:54:50  2013-08-31 23:57:30                    N
#   2013-08-31 23:57:33  2013-09-01 00:10:03                    N
#   2013-08-31 23:58:18  2013-09-01 00:25:07                    N
#   2013-08-31 23:58:58  2013-09-01 00:06:31                    N
# 1 2013-08-31 23:59:14  2013-09-01 00:07:40                    N
#
#                        Lpep_dropoff_datetime  Store_and_fwd_flag  RateCodeID  \
# 2 2013-08-01 08:14:37                      1            0.000000    0.000000
# ...

# %%
df2 = pd.read_csv(r"C:\Users\gaizka\Desktop\UNIR\GAIZKA\ASIGNATURAS\2 Semestre\TFM\codigo\data\fhv_tripdata_2015-01.csv", sep=',')
df2
# Out:
#         Dispatching_base_num          Pickup_date  locationID
# 0                     B00013  2015-01-01 00:30:00         NaN
# 1                     B00013  2015-01-01 01:22:00         NaN
# 2                     B00013  2015-01-01 01:23:00         NaN
# 3                     B00013  2015-01-01 01:44:00         NaN
# 4                     B00013  2015-01-01 02:00:00         NaN
# ...                      ...                  ...         ...
# 2746028               B02765  2015-01-31 23:59:02       169.0
# 2746029               B02765  2015-01-31 23:59:07        80.0
# 2746030               B02765  2015-01-31 23:59:34       186.0
# 2746031               B02765  2015-01-31 23:59:40       181.0
# 2746032               B02765  2015-01-31 23:59:48        79.0
#
# [2746033 rows x 3 columns]

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us")

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("pqfs-mqru", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-7cb4d6b4d2b6> in <module>
#       1 import pandas as pd
# ----> 2 from sodapy import Socrata
#       3
#       4 # Unauthenticated client only works with public data sets. Note 'None'
#       5 # in place of application token, and no username or password:
#
# ModuleNotFoundError: No module named 'sodapy'
