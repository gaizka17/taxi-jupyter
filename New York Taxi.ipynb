# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\109366\Desktop\TFM codigo\data\green_tripdata_2013-08.csv", sep = ",", index_col = None).reset_index()

# %%
df
# Out:
#       level_0              level_1             VendorID lpep_pickup_datetime  \
# 0           2  2013-08-01 08:14:37  2013-08-01 09:09:06                    N
# 1           2  2013-08-01 09:13:00  2013-08-01 11:38:00                    N
# 2           2  2013-08-01 09:48:00  2013-08-01 09:49:00                    N
# 3           2  2013-08-01 10:38:35  2013-08-01 10:38:51                    N
# 4           2  2013-08-01 11:51:45  2013-08-01 12:03:52                    N
# 5           2  2013-08-01 14:33:39  2013-08-01 15:49:00                    N
# 6           2  2013-08-01 17:19:00  2013-08-01 17:19:00                    N
# 7           2  2013-08-01 17:22:00  2013-08-01 17:22:00                    N
# 8           2  2013-08-01 17:24:00  2013-08-01 17:25:00                    N
# 9           2  2013-08-01 19:21:09  2013-08-01 19:22:30                    N
# 10          2  2013-08-01 19:29:27  2013-08-01 19:32:38                    N
# ...

# %%
column_names = df.columns[2:]
df = df.iloc[:,:-2]
df.columns = column_names

# %%
df
# Out:
#       VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0            2  2013-08-01 08:14:37   2013-08-01 09:09:06                  N
# 1            2  2013-08-01 09:13:00   2013-08-01 11:38:00                  N
# 2            2  2013-08-01 09:48:00   2013-08-01 09:49:00                  N
# 3            2  2013-08-01 10:38:35   2013-08-01 10:38:51                  N
# 4            2  2013-08-01 11:51:45   2013-08-01 12:03:52                  N
# 5            2  2013-08-01 14:33:39   2013-08-01 15:49:00                  N
# 6            2  2013-08-01 17:19:00   2013-08-01 17:19:00                  N
# 7            2  2013-08-01 17:22:00   2013-08-01 17:22:00                  N
# 8            2  2013-08-01 17:24:00   2013-08-01 17:25:00                  N
# 9            2  2013-08-01 19:21:09   2013-08-01 19:22:30                  N
# 10           2  2013-08-01 19:29:27   2013-08-01 19:32:38                  N
# ...

# %%
df.columns
# Out:
# Index([u'VendorID', u'lpep_pickup_datetime', u'Lpep_dropoff_datetime',
#        u'Store_and_fwd_flag', u'RateCodeID', u'Pickup_longitude',
#        u'Pickup_latitude', u'Dropoff_longitude', u'Dropoff_latitude',
#        u'Passenger_count', u'Trip_distance', u'Fare_amount', u'Extra',
#        u'MTA_tax', u'Tip_amount', u'Tolls_amount', u'Ehail_fee',
#        u'Total_amount', u'Payment_type', u'Trip_type '],
#       dtype='object')

# %%
df.describe()
# Out:
#           VendorID   RateCodeID  Pickup_longitude  Pickup_latitude  \
# count  7623.000000  7623.000000       7623.000000      7623.000000
# mean      1.929555     1.288076        -68.766738        37.900185
# std       0.255912     4.089259         18.905109        10.407933
# min       1.000000     1.000000       -115.179337         0.000000
# 25%       2.000000     1.000000        -73.946732        40.721142
# 50%       2.000000     1.000000        -73.921158        40.756374
# 75%       2.000000     1.000000        -73.846062        40.804596
# max       2.000000    99.000000          0.000000        40.919121
#
#        Dropoff_longitude  Dropoff_latitude  Passenger_count  Trip_distance  \
# count        7623.000000       7623.000000      7623.000000    7623.000000
# mean          -68.831125         37.927546         2.281779       2.920666
# std            18.808564         10.352452         1.779897       3.402070
# ...

# %%
import numpy as np
df["Trip_type "].dropna()
# Out:
# Series([], Name: Trip_type , dtype: float64)

# %%
df2 = pd.read_csv(r"C:\Users\109366\Desktop\TFM codigo\data\fhv_tripdata_2015-01.csv", sep=',')
df2
# Out:
#         Dispatching_base_num          Pickup_date  locationID
# 0                     B00013  2015-01-01 00:30:00         NaN
# 1                     B00013  2015-01-01 01:22:00         NaN
# 2                     B00013  2015-01-01 01:23:00         NaN
# 3                     B00013  2015-01-01 01:44:00         NaN
# 4                     B00013  2015-01-01 02:00:00         NaN
# 5                     B00013  2015-01-01 02:00:00         NaN
# 6                     B00013  2015-01-01 02:00:00         NaN
# 7                     B00013  2015-01-01 02:50:00         NaN
# 8                     B00013  2015-01-01 04:45:00         NaN
# 9                     B00013  2015-01-01 06:30:00         NaN
# 10                    B00013  2015-01-01 07:15:00         NaN
# 11                    B00013  2015-01-01 07:54:00         NaN
# 12                    B00013  2015-01-01 10:30:00         NaN
# 13                    B00013  2015-01-01 11:00:00         NaN
# ...
